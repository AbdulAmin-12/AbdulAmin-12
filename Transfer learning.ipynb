# %%
# !pip install tensorflow_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.8/dist-packages (0.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow_hub) (3.19.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow_hub) (1.21.6)

# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
IMAGE_SHAPE = (224, 224)

# %%
classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4", input_shape=IMAGE_SHAPE+(3,))
])

# %%
IMAGE_SHAPE+(3,)
# Out:
# (224, 224, 3)

# %%
gold_fish
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-87d335041f8c> in <module>
# ----> 1 gold_fish
#
# NameError: name 'gold_fish' is not defined

# %%
gold_fish = np.array(gold_fish)/255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bf0b0b1bc454> in <module>
# ----> 1 gold_fish = np.array(gold_fish)/255.0
#
# NameError: name 'gold_fish' is not defined

# %%
result = classifier.predict(gold_fish[np.newaxis, ...])
result.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cb2501419b8e> in <module>
# ----> 1 result = classifier.predict(gold_fish[np.newaxis, ...])
#       2 result.shape
#
# NameError: name 'gold_fish' is not defined

# %%
np.argmax(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4094e1b61abb> in <module>
# ----> 1 np.argmax(result)
#
# NameError: name 'result' is not defined

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)

# %%
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/537207677_f96a0507bb.jpg'),
#  PosixPath('datasets/flower_photos/roses/15184419268_7230e9728e.jpg'),
#  PosixPath('datasets/flower_photos/roses/6570546331_ffb9dab0bf_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/21413573151_e681c6a97a.jpg'),
#  PosixPath('datasets/flower_photos/roses/9309388105_12c0b8dd54_m.jpg')]

# %% [markdown]
# # New Section

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
rose = list(data_dir.glob('*/*roses'))

# %%
rose[:5]
# Out:
# []

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/537207677_f96a0507bb.jpg'),
#  PosixPath('datasets/flower_photos/roses/15184419268_7230e9728e.jpg'),
#  PosixPath('datasets/flower_photos/roses/6570546331_ffb9dab0bf_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/21413573151_e681c6a97a.jpg'),
#  PosixPath('datasets/flower_photos/roses/9309388105_12c0b8dd54_m.jpg')]

# %%
pip install Pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (7.1.2)

# %%
import PIL
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x310 at 0x7FC5D84B4E50>

# %%
sunflowers = list(data_dir.glob(('sunflowers/*')))

# %%
sunflowers[:6]
# Out:
# [PosixPath('datasets/flower_photos/sunflowers/21518663809_3d69f5b995_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/14244273988_a7484f18b7_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/3311874685_7b9ef10f7e_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4933821940_38064522a8.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4745991955_6804568ae0_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4933229479_c1708bd503.jpg')]

# %%
PIL.Image.open(sunflowers[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x231 at 0x7FC5D620A0A0>

# %%
for i in range(5):
  PIL.Image.open(str(sunflowers[i]))

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
len(flowers_images_dict['roses'])
# Out:
# 641

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
flowers_images_dict['sunflowers'][:6]
# Out:
# [PosixPath('datasets/flower_photos/sunflowers/21518663809_3d69f5b995_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/14244273988_a7484f18b7_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/3311874685_7b9ef10f7e_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4933821940_38064522a8.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4745991955_6804568ae0_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4933229479_c1708bd503.jpg')]

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
k = cv2.resize(img,(224,224)).shape

# %%
cv2.resize(img,(224,224)).shape
# Out:
# (224, 224, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(224,224))
        X.append(resized_img)

# %%
X = np.asarray(X)
X.shape[1:]
# Out:
# (224, 224, 3)

# %%
X = np.asarray(X)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-43a609905eb5> in <module>
# ----> 1 X = X.reshape(X.shape[1:])
#
# ValueError: cannot reshape array of size 552437760 into shape (224,224,3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(, y, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-59138bc806aa> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(len(X), y, random_state=0)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     267     if hasattr(x, "shape") and x.shape is not None:
#     268         if len(x.shape) == 0:
# --> 269             raise TypeError(
#     270                 "Singleton array %r cannot be considered a valid collection." % x
#     271             )
#
# TypeError: Singleton array array(3670) cannot be considered a valid collection.
