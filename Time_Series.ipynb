# %%
## Install Pandas Data Reader
# !pip install pandas-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
pip install --upgrade pandas-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df_tesla=pdr.get_data_yahoo('TSLA')

# %%
df_tesla.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-08-19  300.359985  292.500000  299.000000  296.666656   61395387.0
# 2022-08-22  292.399994  286.296661  291.913330  289.913330   55843347.0
# 2022-08-23  298.826630  287.923340  291.453339  296.453339   63985044.0
# 2022-08-24  303.646667  296.500000  297.563324  297.096680  168925887.0
# 2022-08-25  302.950012  293.140106  302.359985  295.510010   23326066.0
#
#              Adj Close
# Date
# 2022-08-19  296.666656
# 2022-08-22  289.913330
# 2022-08-23  296.453339
# 2022-08-24  297.096680
# 2022-08-25  295.510010

# %%
close =df_tesla['Close']
ax=close.plot(title='close')
ax.set_xlabel('Date')
ax.set_ylabel('Close')
ax.grid()

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-08-28  23.156666  22.648001  23.152000  23.044001  56459340.0  23.044001
# 2017-08-29  23.270000  22.583332  22.632000  23.157333  61105125.0  23.157333
# 2017-08-30  23.564667  23.133333  23.311333  23.545334  51194145.0  23.545334
# 2017-08-31  23.896000  23.521334  23.570000  23.726665  61091925.0  23.726665
# 2017-09-01  23.839333  23.579346  23.741333  23.693333  45743190.0  23.693333

# %%
df_tesla['High'].plot(figsize=(12,4))

# %%
df_tesla['Volume'].plot(figsize=(12,4))

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4))

# %%
df_tesla['Low'].plot(xlim=['2018-01-01','2019-09-01'],ylim=[0,600],figsize=(12,4))

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-08-28', '2017-08-29', '2017-08-30', '2017-08-31',
#                '2017-09-01', '2017-09-05', '2017-09-06', '2017-09-07',
#                '2017-09-08', '2017-09-11',
#                ...
#                '2022-08-12', '2022-08-15', '2022-08-16', '2022-08-17',
#                '2022-08-18', '2022-08-19', '2022-08-22', '2022-08-23',
#                '2022-08-24', '2022-08-25'],
#               dtype='datetime64[ns]', name='Date', length=1258, freq=None)

# %%
index1 = df_tesla.loc['2017-08-28':'2018-08-28'].plot(kind='line')
index1

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
df_tesla.plot()

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-08-28  23.156666  22.648001  23.152000  23.044001  56459340.0  23.044001
# 2017-08-29  23.270000  22.583332  22.632000  23.157333  61105125.0  23.157333
# 2017-08-30  23.564667  23.133333  23.311333  23.545334  51194145.0  23.545334
# 2017-08-31  23.896000  23.521334  23.570000  23.726665  61091925.0  23.726665
# 2017-09-01  23.839333  23.579346  23.741333  23.693333  45743190.0  23.693333

# %%
df_tesla.loc['2017-08-28':'2017-09-01']
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-08-28  23.156666  22.648001  23.152000  23.044001  56459340.0  23.044001
# 2017-08-29  23.270000  22.583332  22.632000  23.157333  61105125.0  23.157333
# 2017-08-30  23.564667  23.133333  23.311333  23.545334  51194145.0  23.545334
# 2017-08-31  23.896000  23.521334  23.570000  23.726665  61091925.0  23.726665
# 2017-09-01  23.839333  23.579346  23.741333  23.693333  45743190.0  23.693333

# %%
open_data = df_tesla.loc['2017-08-28':'2017-09-01']['Close']
open_data
# Out:
# Date
# 2017-08-28    23.044001
# 2017-08-29    23.157333
# 2017-08-30    23.545334
# 2017-08-31    23.726665
# 2017-09-01    23.693333
# Name: Close, dtype: float64

# %%
share_open=df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364666
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.238327
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
index1=df_tesla.loc['2021-01-01':'2022-09-01'].index
share_close = df_tesla.loc['2021-01-01':'2022-09-01']['Close']

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index1,share_close)

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-08-28  23.156666  22.648001  23.152000  23.044001  56459340.0  23.044001
# 2017-08-29  23.270000  22.583332  22.632000  23.157333  61105125.0  23.157333
# 2017-08-30  23.564667  23.133333  23.311333  23.545334  51194145.0  23.545334
# 2017-08-31  23.896000  23.521334  23.570000  23.726665  61091925.0  23.726665
# 2017-09-01  23.839333  23.579346  23.741333  23.693333  45743190.0  23.693333
#
#                                     date
# Date
# 2017-08-28 1970-01-01 00:00:00.000000000
# 2017-08-29 1970-01-01 00:00:00.000000001
# 2017-08-30 1970-01-01 00:00:00.000000002
# 2017-08-31 1970-01-01 00:00:00.000000003
# 2017-09-01 1970-01-01 00:00:00.000000004

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-08-28  23.156666  22.648001  23.152000  23.044001  56459340.0  23.044001
# 2017-08-29  23.270000  22.583332  22.632000  23.157333  61105125.0  23.157333
# 2017-08-30  23.564667  23.133333  23.311333  23.545334  51194145.0  23.545334
# 2017-08-31  23.896000  23.521334  23.570000  23.726665  61091925.0  23.726665
# 2017-09-01  23.839333  23.579346  23.741333  23.693333  45743190.0  23.693333
#
#                                     date
# Date
# 2017-08-28 1970-01-01 00:00:00.000000000
# 2017-08-29 1970-01-01 00:00:00.000000001
# 2017-08-30 1970-01-01 00:00:00.000000002
# 2017-08-31 1970-01-01 00:00:00.000000003
# 2017-09-01 1970-01-01 00:00:00.000000004

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 8, 25, 15, 57, 38, 455370)

# %%
date=datetime(2021,11,21)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %%
df_tesla.resample(rule='A').min()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-12-31   20.297333   19.508665   19.966665   19.950666  45743190.0
# 2018-12-31   17.355453   16.306005   16.851999   16.704000  46210860.0
# 2019-12-31   12.445333   11.799460   12.073333   11.931333  36984435.0
# 2020-12-31   26.990665   23.367332   24.979767   24.081333  52073166.0
# 2021-12-31  188.736664  179.830002  184.183334  187.666672  29401674.0
# 2022-12-31  217.973328  206.856659  207.949997  209.386673  23326066.0
#
#              Adj Close                          date
# Date
# 2017-12-31   19.950666 1970-01-01 00:00:00.000000000
# 2018-12-31   16.704000 1970-01-01 00:00:00.000000087
# 2019-12-31   11.931333 1970-01-01 00:00:00.000000338
# 2020-12-31   24.081333 1970-01-01 00:00:00.000000590
# 2021-12-31  187.666672 1970-01-01 00:00:00.000000843
# 2022-12-31  209.386673 1970-01-01 00:00:00.000001095

# %%
df_tesla.resample(rule='A').min()['Open'].plot()

# %%
##year end frequency
df_tesla.resample(rule='M')['Close'].plot(kind='bar')
# Out:
# Date
# 2017-08-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-09-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-10-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-11-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-12-31    AxesSubplot(0.125,0.125;0.775x0.755)
#                               ...
# 2022-04-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-06-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-07-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-08-31    AxesSubplot(0.125,0.125;0.775x0.755)
# Freq: M, Name: Close, Length: 61, dtype: object

# %%
import pandas as pd
df_tesla['date'] = pd.to_datetime(df_tesla.index)

# %%
weekly_summary = df_tesla['date'].resample('W').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-6d6857e49e94> in <module>
# ----> 1 weekly_summary = df_tesla['date'].resample('W').sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    5316             level=level,
#    5317             origin=origin,
# -> 5318             offset=offset,
#    5319         )
#    5320
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8137             level=level,
#    8138             origin=origin,
# -> 8139             offset=offset,
#    8140         )
#    8141
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
# ...
